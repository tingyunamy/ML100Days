# %% [markdown]
# ## [作業重點]
# 使用 Sklearn 中的線性迴歸模型，來訓練各種資料集，務必了解送進去模型訓練的**資料型態**為何，也請了解模型中各項參數的意義

# %% [markdown]
# ## 作業
# 試著使用 sklearn datasets 的其他資料集 (wine, boston, ...)，來訓練自己的線性迴歸模型。

# %% [markdown]
# ### HINT: 注意 label 的型態，確定資料集的目標是分類還是回歸，在使用正確的模型訓練！

# %% [markdown]
# wine = datasets.load_wine()
# boston = datasets.load_boston()
# breast_cancer = datasets.load_breast_cancer()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

# %% [markdown]
# # load_wine()

# %%
# 讀取鳶尾花資料集
iris = datasets.load_wine()
# 切分訓練集/測試集
x_train, x_test, y_train, y_test = train_test_split(iris.data[:, :2], iris.target, test_size=0.1, random_state=4)
# 建立模型
logreg = linear_model.LogisticRegression()
# 訓練模型
logreg.fit(x_train, y_train)
# 預測測試集
y_pred = logreg.predict(x_test)

# %%
acc = accuracy_score(y_test, y_pred)
print("Accuracy: ", acc)
# Out:
# Accuracy:  0.7777777777777778

# %%
plt.figure(2, figsize=(8, 6))
# plt.clf()
# Plot the training points
plt.scatter(iris.data[:, 0], iris.data[:, 1], c=iris.target, cmap=plt.cm.Set1)
plt.xticks(())
plt.yticks(())
# Out:
# ([], [])

# %% [markdown]
# # load_boston()

# %%
# 讀取糖尿病資料集
boston = datasets.load_boston()
# X = diabetes.data[:, np.newaxis, 2]
X = diabetes.data
print("Data shape: ", X.shape) 

# 切分訓練集/測試集
x_train, x_test, y_train, y_test = train_test_split(X, boston.target, test_size=0.1, random_state=4)

# 建立一個線性回歸模型
regr = linear_model.LinearRegression()

# 將訓練資料丟進去模型訓練
regr.fit(x_train, y_train)

# 將測試資料丟進模型得到預測結果
y_pred = regr.predict(x_test)
# Out:
# Data shape:  (506, 13)

# %%
print(regr.score(x_test, y_test))
# Out:
# 0.7926083526613232

# %% [markdown]
# # load_breast_cancer

# %%
# 讀取鳶尾花資料集
breast_cancer = datasets.load_breast_cancer()
# 切分訓練集/測試集
x_train, x_test, y_train, y_test = train_test_split(breast_cancer.data, breast_cancer.target, test_size=0.1, random_state=4)
# 建立模型
logreg = linear_model.LogisticRegression()
# 訓練模型
logreg.fit(x_train, y_train)
# 預測測試集
y_pred = logreg.predict(x_test)
# Out:
# C:\Users\tingyunamy\.conda\envs\ML\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
acc = accuracy_score(y_test, y_pred)
print("Accuracy: ", acc)
# Out:
# Accuracy:  0.8070175438596491

# %%
plt.figure(2, figsize=(8, 6))
# plt.clf()
# Plot the training points
plt.scatter(breast_cancer.data[:, 0], breast_cancer.data[:, 1], c=breast_cancer.target, cmap=plt.cm.Set1)
plt.xticks(())
plt.yticks(())
# Out:
# ([], [])
